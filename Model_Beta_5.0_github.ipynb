# %% [markdown]
# # Betting Support Model (4.0 Beta Version) - La Liga

# %% [markdown]
# ## Scrapping the data
# For now we will be manually copying and pastying the tables on an Excel file. Tried using BeautifulSoup, requests, and Selenium for scrapping the data, but the JSON format in the HTML make things hard.

# %% [markdown]
# ## Clean and Manipulate Data

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import numpy as np

# Load the dataset
df_overall = pd.read_excel('xG_dataset_laliga.xlsx', sheet_name = "Overall")
df_home = pd.read_excel('xG_dataset_laliga.xlsx', sheet_name = "Home")
df_away = pd.read_excel('xG_dataset_laliga.xlsx', sheet_name = "Away")


# Split the values in the xG, xGA, and xPTS columns on the space character and select the first element
df_overall['xG'] = pd.to_numeric(df_overall['xG'].str.split().str[0])
df_overall['xGA'] = pd.to_numeric(df_overall['xGA'].str.split().str[0])
df_overall['xPTS'] = pd.to_numeric(df_overall['xPTS'].str.split().str[0])

df_home['xG'] = pd.to_numeric(df_home['xG'].str.split().str[0])
df_home['xGA'] = pd.to_numeric(df_home['xGA'].str.split().str[0])
df_home['xPTS'] = pd.to_numeric(df_home['xPTS'].str.split().str[0])

df_away['xG'] = pd.to_numeric(df_away['xG'].str.split().str[0])
df_away['xGA'] = pd.to_numeric(df_away['xGA'].str.split().str[0])
df_away['xPTS'] = pd.to_numeric(df_away['xPTS'].str.split().str[0])

# %%
# Adding the Ratios

list_metric = ["xG", "xGA", "xPTS"]
list_naming = ["xG per Game", "xGA per Game", "xPTS per Game"]

# Loop for Overall
counter = 0
while counter < len(list_metric):
    df_overall[list_naming[counter]] = df_overall[list_metric[counter]] / df_overall["M"]
    counter += 1

# Adding performance difference    

for i in range(len(df_overall)):
    xG_per_game_diff = df_overall.loc[i, "G"] / df_overall.loc[i, "M"] - df_overall.loc[i, "xG per Game"]
    xGA_per_game_diff = df_overall.loc[i, "xGA per Game"] -  df_overall.loc[i, "GA"] / df_overall.loc[i, "M"]  
    df_overall.loc[i, "xG per Game Diff"] = xG_per_game_diff
    df_overall.loc[i, "xGA per Game Diff"] = xGA_per_game_diff
    
df_overall.head(3)
# Out:
#    №           Team   M   W  D  L   G  GA  PTS     xG    xGA   xPTS  \
# 0  1      Barcelona  21  18  2  1  43   7   56  49.48  16.61  45.76
# 1  2    Real Madrid  22  16  3  3  46  17   51  48.14  20.83  47.89
# 2  3  Real Sociedad  22  13  4  5  32  22   43  35.70  20.84  41.25
#
#    xG per Game  xGA per Game  xPTS per Game  xG per Game Diff  \
# 0     2.356190      0.790952       2.179048         -0.308571
# 1     2.188182      0.946818       2.176818         -0.097273
# 2     1.622727      0.947273       1.875000         -0.168182
#
#    xGA per Game Diff
# 0           0.457619
# 1           0.174091
# 2          -0.052727

# %%
# Loop for Home    
counter = 0
while counter < len(list_metric):
    df_home[list_naming[counter]] = df_home[list_metric[counter]] / df_home["M"]
    counter += 1

for i in range(len(df_home)):
    xG_per_game_diff = df_home.loc[i, "G"] / df_home.loc[i, "M"] - df_home.loc[i, "xG per Game"]
    xGA_per_game_diff = df_home.loc[i, "xGA per Game"] -  df_home.loc[i, "GA"] / df_home.loc[i, "M"]  
    df_home.loc[i, "xG per Game Diff"] = xG_per_game_diff
    df_home.loc[i, "xGA per Game Diff"] = xGA_per_game_diff    
    
df_home.head(3)
# Out:
#    №         Team   M  W  D  L   G  GA  PTS     xG    xGA   xPTS  xG per Game  \
# 0  1    Barcelona  10  8  2  0  22   1   26  28.46   6.27  24.60       2.8460
# 1  2  Real Madrid  10  7  3  0  22   7   24  24.07   8.25  23.41       2.4070
# 2  3       Girona  12  6  3  3  23  17   21  21.51  12.12  22.49       1.7925
#
#    xGA per Game  xPTS per Game  xG per Game Diff  xGA per Game Diff
# 0         0.627       2.460000         -0.646000           0.527000
# 1         0.825       2.341000         -0.207000           0.125000
# 2         1.010       1.874167          0.124167          -0.406667

# %%
# Loop for Away 
counter = 0
while counter < len(list_metric):
    df_away[list_naming[counter]] = df_away[list_metric[counter]] / df_away["M"]
    counter += 1

for i in range(len(df_away)):
    xG_per_game_diff = df_away.loc[i, "G"] / df_away.loc[i, "M"] - df_away.loc[i, "xG per Game"]
    xGA_per_game_diff = df_away.loc[i, "xGA per Game"] -  df_away.loc[i, "GA"] / df_away.loc[i, "M"]  
    df_away.loc[i, "xG per Game Diff"] = xG_per_game_diff
    df_away.loc[i, "xGA per Game Diff"] = xGA_per_game_diff     
    
       
df_away.head(3)
# Out:
#    №           Team   M   W  D  L   G  GA  PTS     xG    xGA   xPTS  \
# 0  1      Barcelona  11  10  0  1  21   6   30  21.02  10.34  21.16
# 1  2    Real Madrid  12   9  0  3  24  10   27  24.07  12.58  24.49
# 2  3  Real Sociedad  11   8  1  2  19  10   25  17.34   9.11  20.89
#
#    xG per Game  xGA per Game  xPTS per Game  xG per Game Diff  \
# 0     1.910909      0.940000       1.923636         -0.001818
# 1     2.005833      1.048333       2.040833         -0.005833
# 2     1.576364      0.828182       1.899091          0.150909
#
#    xGA per Game Diff
# 0           0.394545
# 1           0.215000
# 2          -0.080909

# %%
# Set display options
pd.set_option("display.max_rows", None)  # Display all rows
pd.set_option("display.max_columns", None)  # Display all columns
pd.set_option("display.width", None)  # Set display width to auto

# Merge dataframes on 'team' column
df_merged_1 = pd.merge(df_home, df_away, on='Team')
df_merged = pd.merge(df_overall, df_merged_1, on="Team")
df_merged
# Out:
#      №             Team   M   W  D   L   G  GA  PTS     xG    xGA   xPTS  \
# 0    1        Barcelona  21  18  2   1  43   7   56  49.48  16.61  45.76
# 1    2      Real Madrid  22  16  3   3  46  17   51  48.14  20.83  47.89
# 2    3    Real Sociedad  22  13  4   5  32  22   43  35.70  20.84  41.25
# 3    4  Atletico Madrid  21  11  5   5  30  17   38  33.98  23.46  34.76
# 4    5       Real Betis  22  11  4   7  29  23   37  34.28  30.49  32.33
# 5    6   Rayo Vallecano  21   9  6   6  28  23   33  25.63  27.23  27.68
# 6    7    Athletic Club  21   9  5   7  31  22   32  31.72  18.43  37.03
# 7    8       Villarreal  22   9  4   9  24  22   31  31.65  31.49  31.31
# 8    9         Mallorca  22   9  4   9  20  22   31  22.67  24.66  28.67
# 9   10          Osasuna  22   8  6   8  19  21   30  25.25  28.30  27.12
# 10  11           Girona  22   7  6   9  33  33   27  34.18  29.02  33.28
# 11  12          Sevilla  21   6  6   9  23  29   24  24.40  36.06  22.81
# 12  13       Celta Vigo  22   6  6  10  23  34   24  24.81  26.01  29.78
# 13  14  Real Valladolid  22   7  3  12  16  30   24  22.54  37.42  21.32
# 14  15          Almeria  22   6  4  12  27  40   22  26.12  42.97  21.10
# 15  16            Cadiz  21   5  7   9  17  33   22  19.24  37.20  18.75
# 16  17         Espanyol  21   4  9   8  26  33   21  26.14  28.61  27.45
# 17  18         Valencia  21   5  5  11  26  26   20  31.57  29.08  31.00
# 18  19           Getafe  21   4  7  10  18  28   19  17.49  25.65  21.93
# 19  20            Elche  21   1  6  14  15  44    9  18.26  48.89  15.20
#
#     xG per Game  xGA per Game  xPTS per Game  xG per Game Diff  \
# 0      2.356190      0.790952       2.179048         -0.308571
# 1      2.188182      0.946818       2.176818         -0.097273
# 2      1.622727      0.947273       1.875000         -0.168182
# 3      1.618095      1.117143       1.655238         -0.189524
# 4      1.558182      1.385909       1.469545         -0.240000
# 5      1.220476      1.296667       1.318095          0.112857
# 6      1.510476      0.877619       1.763333         -0.034286
# 7      1.438636      1.431364       1.423182         -0.347727
# 8      1.030455      1.120909       1.303182         -0.121364
# 9      1.147727      1.286364       1.232727         -0.284091
# 10     1.553636      1.319091       1.512727         -0.053636
# 11     1.161905      1.717143       1.086190         -0.066667
# 12     1.127727      1.182273       1.353636         -0.082273
# 13     1.024545      1.700909       0.969091         -0.297273
# 14     1.187273      1.953182       0.959091          0.040000
# 15     0.916190      1.771429       0.892857         -0.106667
# 16     1.244762      1.362381       1.307143         -0.006667
# 17     1.503333      1.384762       1.476190         -0.265238
# 18     0.832857      1.221429       1.044286          0.024286
# 19     0.869524      2.328095       0.723810         -0.155238
#
#     xGA per Game Diff  №_x  M_x  W_x  D_x  L_x  G_x  GA_x  PTS_x   xG_x  \
# 0            0.457619    1   10    8    2    0   22     1     26  28.46
# 1            0.174091    2   10    7    3    0   22     7     24  24.07
# 2           -0.052727    9   11    5    3    3   13    12     18  18.36
# 3            0.307619   13   10    4    3    3   15    10     15  17.46
# 4            0.340455    5   11    6    2    3   18    12     20  20.33
# 5            0.201429   11   10    5    2    3   15    11     17  14.05
# 6           -0.170000    4   11    6    2    3   16     7     20  19.02
# 7            0.431364    7   10    6    1    3   14     8     19  18.96
# 8            0.120909    6   11    6    2    3   12     8     20  13.24
# 9            0.331818   10   11    6    0    5   12    11     18  17.05
# 10          -0.180909    3   12    6    3    3   23    17     21  21.51
# 11           0.336190   14   11    4    3    4   12    12     15  15.69
# 12          -0.363182   17   11    3    4    4   13    14     13  11.99
# 13           0.337273   12   11    5    2    4    9     9     17  15.45
# 14           0.135000    8   11    6    1    4   19    15     19  14.50
# 15           0.200000   16   11    3    5    3   11    15     14  11.05
# 16          -0.209048   19   11    2    4    5   14    19     10  16.56
# 17           0.146667   15   11    4    2    5   18    12     14  18.80
# 18          -0.111905   18   11    2    4    5   10    14     10   9.79
# 19           0.232857   20   10    1    3    6    8    16      6  12.81
#
#     xGA_x  xPTS_x  xG per Game_x  xGA per Game_x  xPTS per Game_x  \
# 0    6.27   24.60       2.846000        0.627000         2.460000
# 1    8.25   23.41       2.407000        0.825000         2.341000
# 2   11.73   20.36       1.669091        1.066364         1.850909
# 3   10.96   17.07       1.746000        1.096000         1.707000
# 4   14.22   18.03       1.848182        1.292727         1.639091
# 5   11.44   14.63       1.405000        1.144000         1.463000
# 6    7.41   23.41       1.729091        0.673636         2.128182
# 7    9.11   19.57       1.896000        0.911000         1.957000
# 8    9.45   18.11       1.203636        0.859091         1.646364
# 9   12.81   17.48       1.550000        1.164545         1.589091
# 10  12.12   22.49       1.792500        1.010000         1.874167
# 11  15.75   16.50       1.426364        1.431818         1.500000
# 12   9.62   16.99       1.090000        0.874545         1.544545
# 13  11.82   17.17       1.404545        1.074545         1.560909
# 14  19.14   12.50       1.318182        1.740000         1.136364
# 15  17.83   12.08       1.004545        1.620909         1.098182
# 16  13.66   17.39       1.505455        1.241818         1.580909
# 17  11.93   19.90       1.709091        1.084545         1.809091
# 18  13.61   11.81       0.890000        1.237273         1.073636
# 19  16.98   11.65       1.281000        1.698000         1.165000
#
#     xG per Game Diff_x  xGA per Game Diff_x  №_y  M_y  W_y  D_y  L_y  G_y  \
# 0            -0.646000             0.527000    1   11   10    0    1   21
# 1            -0.207000             0.125000    2   12    9    0    3   24
# 2            -0.487273            -0.024545    3   11    8    1    2   19
# 3            -0.246000             0.096000    4   11    7    2    2   15
# 4            -0.211818             0.201818    5   11    5    2    4   11
# 5             0.095000             0.044000    6   11    4    4    3   13
# 6            -0.274545             0.037273    7   10    3    3    4   15
# 7            -0.496000             0.111000    9   12    3    3    6   10
# 8            -0.112727             0.131818   11   11    3    2    6    8
# 9            -0.459091             0.164545    8   11    2    6    3    7
# 10            0.124167            -0.406667   17   10    1    3    6   10
# 11           -0.335455             0.340909   13   10    2    3    5   11
# 12            0.091818            -0.398182   12   11    3    2    6   10
# 13           -0.586364             0.256364   16   11    2    1    8    7
# 14            0.409091             0.376364   19   11    0    3    8    8
# 15           -0.004545             0.257273   15   10    2    2    6    6
# 16           -0.232727            -0.485455   10   10    2    5    3   12
# 17           -0.072727            -0.006364   18   10    1    3    6    8
# 18            0.019091            -0.035455   14   10    2    3    5    8
# 19           -0.481000             0.098000   20   11    0    3    8    7
#
#     GA_y  PTS_y   xG_y  xGA_y  xPTS_y  xG per Game_y  xGA per Game_y  \
# 0      6     30  21.02  10.34   21.16       1.910909        0.940000
# 1     10     27  24.07  12.58   24.49       2.005833        1.048333
# 2     10     25  17.34   9.11   20.89       1.576364        0.828182
# 3      7     23  16.52  12.51   17.70       1.501818        1.137273
# 4     11     17  13.95  16.27   14.30       1.268182        1.479091
# 5     12     16  11.58  15.79   13.05       1.052727        1.435455
# 6     15     12  12.70  11.02   13.62       1.270000        1.102000
# 7     14     12  12.69  22.37   11.75       1.057500        1.864167
# 8     14     11   9.43  15.21   10.56       0.857273        1.382727
# 9     10     12   8.20  15.49    9.64       0.745455        1.408182
# 10    16      6  12.67  16.90   10.79       1.267000        1.690000
# 11    17      9   8.71  20.31    6.31       0.871000        2.031000
# 12    20     11  12.82  16.39   12.80       1.165455        1.490000
# 13    21      7   7.09  25.60    4.15       0.644545        2.327273
# 14    25      3  11.62  23.82    8.61       1.056364        2.165455
# 15    18      8   8.19  19.37    6.66       0.819000        1.937000
# 16    14     11   9.59  14.95   10.06       0.959000        1.495000
# 17    14      6  12.77  17.15   11.10       1.277000        1.715000
# 18    14      9   7.70  12.04   10.12       0.770000        1.204000
# 19    28      3   5.45  31.91    3.55       0.495455        2.900909
#
#     xPTS per Game_y  xG per Game Diff_y  xGA per Game Diff_y
# 0          1.923636           -0.001818             0.394545
# 1          2.040833           -0.005833             0.215000
# 2          1.899091            0.150909            -0.080909
# 3          1.609091           -0.138182             0.500909
# 4          1.300000           -0.268182             0.479091
# 5          1.186364            0.129091             0.344545
# 6          1.362000            0.230000            -0.398000
# 7          0.979167           -0.224167             0.697500
# 8          0.960000           -0.130000             0.110000
# 9          0.876364           -0.109091             0.499091
# 10         1.079000           -0.267000             0.090000
# 11         0.631000            0.229000             0.331000
# 12         1.163636           -0.256364            -0.328182
# 13         0.377273           -0.008182             0.418182
# 14         0.782727           -0.329091            -0.107273
# 15         0.666000           -0.219000             0.137000
# 16         1.006000            0.241000             0.095000
# 17         1.110000           -0.477000             0.315000
# 18         1.012000            0.030000            -0.196000
# 19         0.322727            0.140909             0.355455

# %% [markdown]
# Tomorrow games include:
#
# - Elche (home) vs Espanyol (away)
# - Rayo Vallecano (home) vs Sevilla (away)
# - Atletico Madrid (home) vs Athletic Club (away)
# - Barcelona (home) vs Cadiz (away)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Predictions

# %% [markdown]
# To determine the likelihood of the Barcelona vs Cadiz game to have over 2 goals based on the provided data, we can use the Poisson distribution, which is commonly used in soccer to model the number of goals scored in a match.
#
# The Poisson distribution has one parameter, λ, which represents the expected number of goals scored by a team in a match. The probability of a team scoring exactly k goals is given by the following formula:
#
# P(k;λ) = (e^-λ * λ^k) / k!
#
# To calculate the probability of a match having over 2 goals, we need to calculate the probability of both teams scoring 1 or more goals, which is given by:
#
# P(Barcelona > 0; λB) * P(Cadiz > 0; λC)
#
# where P(Barcelona > 0; λB) is the probability of Barcelona scoring at least one goal, which is equal to:
#
# P(Barcelona > 0; λB) = 1 - P(Barcelona = 0; λB)
#
# and P(Barcelona = 0; λB) is the probability of Barcelona not scoring any goals, which is given by:
#
# P(Barcelona = 0; λB) = e^-λB
#
# where λB is the expected number of goals scored by Barcelona in the match. We can estimate λB as the product of Barcelona's overall xG and Cadiz's overall xGA, which gives:
#
# λB = 2.35 * 1.77 = 4.1655
#
# Similarly, we can estimate λC as the product of Cadiz's overall xG and Barcelona's overall xGA, which gives:
#
# λC = 0.91 * 0.79 = 0.719
#
# Using these values, we can calculate the probability of both teams scoring 1 or more goals as:
#
# P(Barcelona > 0; λB) * P(Cadiz > 0; λC) = (1 - e^-λB) * (1 - e^-λC) = 0.925
#
# This means that the probability of the match having over 2 goals is 92.5%.

# %%
import numpy as np
from scipy.stats import poisson

# Assuming the main dataframe is named "df_merged"

# Get Barcelona home stats
barcelona_home_stats = df_merged.loc[df_merged['Team'] == 'Barcelona', ['xG per Game_x', 'xGA per Game_x', 'xG per Game Diff_x', 'xGA per Game Diff_x']]
barcelona_home_xG = barcelona_home_stats['xG per Game_x'].values[0]
barcelona_home_xGA = barcelona_home_stats['xGA per Game_x'].values[0]
barcelona_home_xG_diff = barcelona_home_stats['xG per Game Diff_x'].values[0]
barcelona_home_xGA_diff = barcelona_home_stats['xGA per Game Diff_x'].values[0]

# Get Cadiz away stats
cadiz_away_stats = df_merged.loc[df_merged['Team'] == 'Cadiz', ['xG per Game_y', 'xGA per Game_y', 'xG per Game Diff_y', 'xGA per Game Diff_y']]
cadiz_away_xG = cadiz_away_stats['xG per Game_y'].values[0]
cadiz_away_xGA = cadiz_away_stats['xGA per Game_y'].values[0]
cadiz_away_xG_diff = cadiz_away_stats['xG per Game Diff_y'].values[0]
cadiz_away_xGA_diff = cadiz_away_stats['xGA per Game Diff_y'].values[0]


# Calculate lambda for Barcelona scoring at home and Cadiz conceding away
lambda_barcelona = (barcelona_home_xG + barcelona_home_xG_diff) * (cadiz_away_xGA - cadiz_away_xGA_diff)
lambda_cadiz = (cadiz_away_xG + cadiz_away_xG_diff) * (barcelona_home_xGA - barcelona_home_xGA_diff)

# Calculate the probability of Barcelona scoring x goals at home and Cadiz conceding x goals away
prob = 0
for i in range(3):
    for j in range(3):
        prob += poisson.pmf(i, lambda_barcelona) * poisson.pmf(j, lambda_cadiz)
        
# Calculate the probability of over 2 goals
prob_over_2 = 1 - poisson.cdf(2, lambda_barcelona) * poisson.cdf(2, lambda_cadiz)

# Calculate total expected goals
lambda_total = lambda_barcelona + lambda_cadiz

print("The probability of the Barcelona vs Cadiz game ending with over 2 goals is: {:.3f}".format(prob_over_2))
print("Total expected goals anticipated:", lambda_total)
# Out:
# The probability of the Barcelona vs Cadiz game ending with over 2 goals is: 0.756
# Total expected goals anticipated: 4.0200000000000005

# %%
# Run the simulation 1 times
for n in range(1):
    print(f"Simulation {n+1}:")
    for i in range(3):
        for j in range(3):
            score_prob = poisson.pmf(i, lambda_barcelona) * poisson.pmf(j, lambda_cadiz)
            print(f"Barcelona {i} - {j} Cadiz ({score_prob:.3f})")
# Out:
# Simulation 1:
# Barcelona 0 - 0 Cadiz (0.018)
# Barcelona 0 - 1 Cadiz (0.001)
# Barcelona 0 - 2 Cadiz (0.000)
# Barcelona 1 - 0 Cadiz (0.071)
# Barcelona 1 - 1 Cadiz (0.004)
# Barcelona 1 - 2 Cadiz (0.000)
# Barcelona 2 - 0 Cadiz (0.141)
# Barcelona 2 - 1 Cadiz (0.008)
# Barcelona 2 - 2 Cadiz (0.000)

# %% [markdown]
# ## Create the Function

# %%
def predict_game_result(home_team, away_team, df_merged):
    from scipy.stats import poisson

    # Get home team stats
    home_stats = df_merged.loc[df_merged['Team'] == home_team, ['xG per Game_x', 'xGA per Game_x', 'xG per Game Diff_x', 'xGA per Game Diff_x']]
    home_xG = home_stats['xG per Game_x'].values[0]
    home_xGA = home_stats['xGA per Game_x'].values[0]
    home_xG_diff = home_stats['xG per Game Diff_x'].values[0]
    home_xGA_diff = home_stats['xGA per Game Diff_x'].values[0]

    # Get away team stats
    away_stats = df_merged.loc[df_merged['Team'] == away_team, ['xG per Game_y', 'xGA per Game_y', 'xG per Game Diff_y', 'xGA per Game Diff_y']]
    away_xG = away_stats['xG per Game_y'].values[0]
    away_xGA = away_stats['xGA per Game_y'].values[0]
    away_xG_diff = away_stats['xG per Game Diff_y'].values[0]
    away_xGA_diff = away_stats['xGA per Game Diff_y'].values[0]

    # Calculate lambda for home team scoring at home and away team conceding away
    lambda_home = (home_xG + home_xG_diff) * (away_xGA - away_xGA_diff)
    lambda_away = (away_xG + away_xG_diff) * (home_xGA - home_xGA_diff)

    # Calculate the probability of the home team scoring x goals at home and the away team conceding x goals away
    prob = 0
    for i in range(3):
        for j in range(3):
            prob += poisson.pmf(i, lambda_home) * poisson.pmf(j, lambda_away)
    
    max_score=6
    for n in range(1):
        print(f"Simulation {n+1}:")
        for i in range(max_score+1):
            for j in range(max_score+1):
                score_prob = poisson.pmf(i, lambda_home) * poisson.pmf(j, lambda_away)
                print(f"{home_team} {i} - {j} {away_team} ({score_prob:.3f})")
      
    

    # Calculate the probability of over 2 goals
    prob_over_2 = 1 - poisson.cdf(2, lambda_home) * poisson.cdf(2, lambda_away)

    # Calculate total expected goals
    lambda_total = lambda_home + lambda_away
    

    return {"home_team": home_team, "away_team": away_team, "lambda_home": lambda_home, "lambda_away": lambda_away, 
            "prob_over_2_goals": prob_over_2, "expected_goals": lambda_total}

# %% [markdown]
# # Predictions

# %%
predict_game_result('Barcelona', 'Cadiz', df_merged)
# Out:
# Simulation 1:
# Barcelona 0 - 0 Cadiz (0.018)
# Barcelona 0 - 1 Cadiz (0.001)
# Barcelona 0 - 2 Cadiz (0.000)
# Barcelona 0 - 3 Cadiz (0.000)
# Barcelona 0 - 4 Cadiz (0.000)
# Barcelona 1 - 0 Cadiz (0.071)
# Barcelona 1 - 1 Cadiz (0.004)
# Barcelona 1 - 2 Cadiz (0.000)
# Barcelona 1 - 3 Cadiz (0.000)
# Barcelona 1 - 4 Cadiz (0.000)
# Barcelona 2 - 0 Cadiz (0.141)
# Barcelona 2 - 1 Cadiz (0.008)
# Barcelona 2 - 2 Cadiz (0.000)
# Barcelona 2 - 3 Cadiz (0.000)
# Barcelona 2 - 4 Cadiz (0.000)
# Barcelona 3 - 0 Cadiz (0.186)
# Barcelona 3 - 1 Cadiz (0.011)
# Barcelona 3 - 2 Cadiz (0.000)
# Barcelona 3 - 3 Cadiz (0.000)
# Barcelona 3 - 4 Cadiz (0.000)
# Barcelona 4 - 0 Cadiz (0.184)
# Barcelona 4 - 1 Cadiz (0.011)
# Barcelona 4 - 2 Cadiz (0.000)
# Barcelona 4 - 3 Cadiz (0.000)
# Barcelona 4 - 4 Cadiz (0.000)
# {'home_team': 'Barcelona',
#  'away_team': 'Cadiz',
#  'lambda_home': 3.9600000000000004,
#  'lambda_away': 0.059999999999999984,
#  'prob_over_2_goals': 0.7559852854220809,
#  'expected_goals': 4.0200000000000005}

# %%
predict_game_result('Getafe', 'Valencia', df_merged)
# Out:
# Simulation 1:
# Getafe 0 - 0 Valencia (0.101)
# Getafe 0 - 1 Valencia (0.103)
# Getafe 0 - 2 Valencia (0.052)
# Getafe 0 - 3 Valencia (0.018)
# Getafe 0 - 4 Valencia (0.005)
# Getafe 1 - 0 Valencia (0.129)
# Getafe 1 - 1 Valencia (0.131)
# Getafe 1 - 2 Valencia (0.067)
# Getafe 1 - 3 Valencia (0.023)
# Getafe 1 - 4 Valencia (0.006)
# Getafe 2 - 0 Valencia (0.082)
# Getafe 2 - 1 Valencia (0.083)
# Getafe 2 - 2 Valencia (0.042)
# Getafe 2 - 3 Valencia (0.014)
# Getafe 2 - 4 Valencia (0.004)
# Getafe 3 - 0 Valencia (0.035)
# Getafe 3 - 1 Valencia (0.035)
# Getafe 3 - 2 Valencia (0.018)
# Getafe 3 - 3 Valencia (0.006)
# Getafe 3 - 4 Valencia (0.002)
# Getafe 4 - 0 Valencia (0.011)
# Getafe 4 - 1 Valencia (0.011)
# Getafe 4 - 2 Valencia (0.006)
# Getafe 4 - 3 Valencia (0.002)
# Getafe 4 - 4 Valencia (0.000)
# {'home_team': 'Getafe',
#  'away_team': 'Valencia',
#  'lambda_home': 1.2727272727272727,
#  'lambda_away': 1.0181818181818183,
#  'prob_over_2_goals': 0.20889504627016475,
#  'expected_goals': 2.290909090909091}

# %% [markdown]
# ## Entire Matchday Predictions

# %%
import pandas as pd

home_teams = ["Girona", "Real Sociedad", "Real Betis", "Mallorca", "Osasuna", "Elche", "Rayo Vallecano", "Atletico Madrid", "Barcelona", "Getafe"]
away_teams = ["Almeria", "Celta Vigo", "Real Valladolid", "Villarreal", "Real Madrid", "Espanyol", "Sevilla", "Athletic Club", "Cadiz", "Valencia"]

# Create a dataframe with the home and away teams for each matchday
df_matchdays = pd.DataFrame({'home_team': home_teams, 'away_team': away_teams})

# Print the dataframe
print(df_matchdays)
# Out:
#          home_team        away_team
# 0           Girona          Almeria
# 1    Real Sociedad       Celta Vigo
# 2       Real Betis  Real Valladolid
# 3         Mallorca       Villarreal
# 4          Osasuna      Real Madrid
# 5            Elche         Espanyol
# 6   Rayo Vallecano          Sevilla
# 7  Atletico Madrid    Athletic Club
# 8        Barcelona            Cadiz
# 9           Getafe         Valencia

# %%
for i, row in df_matchdays.iterrows():
    home_team = row['home_team']
    away_team = row['away_team']
    print(f"Match {i+1}: {home_team} vs {away_team}")
    print(" ")
    result = predict_game_result(home_team, away_team, df_merged)
    print(result)
    print(" ")
# Out:
# Match 1: Girona vs Almeria
#
# Simulation 1:
# Girona 0 - 0 Almeria (0.005)
# Girona 0 - 1 Almeria (0.005)
# Girona 0 - 2 Almeria (0.002)
# Girona 0 - 3 Almeria (0.001)
# Girona 0 - 4 Almeria (0.000)
# Girona 0 - 5 Almeria (0.000)
# Girona 0 - 6 Almeria (0.000)
# Girona 1 - 0 Almeria (0.020)
# Girona 1 - 1 Almeria (0.021)
# Girona 1 - 2 Almeria (0.011)
# Girona 1 - 3 Almeria (0.004)
# Girona 1 - 4 Almeria (0.001)
# Girona 1 - 5 Almeria (0.000)
# Girona 1 - 6 Almeria (0.000)
# Girona 2 - 0 Almeria (0.043)
# Girona 2 - 1 Almeria (0.045)
# Girona 2 - 2 Almeria (0.023)
# Girona 2 - 3 Almeria (0.008)
# Girona 2 - 4 Almeria (0.002)
# Girona 2 - 5 Almeria (0.000)
# Girona 2 - 6 Almeria (0.000)
# Girona 3 - 0 Almeria (0.063)
# Girona 3 - 1 Almeria (0.065)
# Girona 3 - 2 Almeria (0.033)
# Girona 3 - 3 Almeria (0.011)
# Girona 3 - 4 Almeria (0.003)
# Girona 3 - 5 Almeria (0.001)
# Girona 3 - 6 Almeria (0.000)
# Girona 4 - 0 Almeria (0.069)
# Girona 4 - 1 Almeria (0.071)
# Girona 4 - 2 Almeria (0.036)
# Girona 4 - 3 Almeria (0.013)
# Girona 4 - 4 Almeria (0.003)
# Girona 4 - 5 Almeria (0.001)
# Girona 4 - 6 Almeria (0.000)
# Girona 5 - 0 Almeria (0.060)
# Girona 5 - 1 Almeria (0.062)
# Girona 5 - 2 Almeria (0.032)
# Girona 5 - 3 Almeria (0.011)
# Girona 5 - 4 Almeria (0.003)
# Girona 5 - 5 Almeria (0.001)
# Girona 5 - 6 Almeria (0.000)
# Girona 6 - 0 Almeria (0.043)
# Girona 6 - 1 Almeria (0.045)
# Girona 6 - 2 Almeria (0.023)
# Girona 6 - 3 Almeria (0.008)
# Girona 6 - 4 Almeria (0.002)
# Girona 6 - 5 Almeria (0.000)
# Girona 6 - 6 Almeria (0.000)
# {'home_team': 'Girona', 'away_team': 'Almeria', 'lambda_home': 4.356060606060606, 'lambda_away': 1.0303030303030303, 'prob_over_2_goals': 0.8259417623896992, 'expected_goals': 5.386363636363637}
#
# Match 2: Real Sociedad vs Celta Vigo
#
# Simulation 1:
# Real Sociedad 0 - 0 Celta Vigo (0.043)
# Real Sociedad 0 - 1 Celta Vigo (0.043)
# Real Sociedad 0 - 2 Celta Vigo (0.021)
# Real Sociedad 0 - 3 Celta Vigo (0.007)
# Real Sociedad 0 - 4 Celta Vigo (0.002)
# Real Sociedad 0 - 5 Celta Vigo (0.000)
# Real Sociedad 0 - 6 Celta Vigo (0.000)
# Real Sociedad 1 - 0 Celta Vigo (0.093)
# Real Sociedad 1 - 1 Celta Vigo (0.092)
# Real Sociedad 1 - 2 Celta Vigo (0.046)
# Real Sociedad 1 - 3 Celta Vigo (0.015)
# Real Sociedad 1 - 4 Celta Vigo (0.004)
# Real Sociedad 1 - 5 Celta Vigo (0.001)
# Real Sociedad 1 - 6 Celta Vigo (0.000)
# Real Sociedad 2 - 0 Celta Vigo (0.100)
# Real Sociedad 2 - 1 Celta Vigo (0.099)
# Real Sociedad 2 - 2 Celta Vigo (0.049)
# Real Sociedad 2 - 3 Celta Vigo (0.016)
# Real Sociedad 2 - 4 Celta Vigo (0.004)
# Real Sociedad 2 - 5 Celta Vigo (0.001)
# Real Sociedad 2 - 6 Celta Vigo (0.000)
# Real Sociedad 3 - 0 Celta Vigo (0.072)
# Real Sociedad 3 - 1 Celta Vigo (0.071)
# Real Sociedad 3 - 2 Celta Vigo (0.035)
# Real Sociedad 3 - 3 Celta Vigo (0.012)
# Real Sociedad 3 - 4 Celta Vigo (0.003)
# Real Sociedad 3 - 5 Celta Vigo (0.001)
# Real Sociedad 3 - 6 Celta Vigo (0.000)
# Real Sociedad 4 - 0 Celta Vigo (0.038)
# Real Sociedad 4 - 1 Celta Vigo (0.038)
# Real Sociedad 4 - 2 Celta Vigo (0.019)
# Real Sociedad 4 - 3 Celta Vigo (0.006)
# Real Sociedad 4 - 4 Celta Vigo (0.002)
# Real Sociedad 4 - 5 Celta Vigo (0.000)
# Real Sociedad 4 - 6 Celta Vigo (0.000)
# Real Sociedad 5 - 0 Celta Vigo (0.017)
# Real Sociedad 5 - 1 Celta Vigo (0.016)
# Real Sociedad 5 - 2 Celta Vigo (0.008)
# Real Sociedad 5 - 3 Celta Vigo (0.003)
# Real Sociedad 5 - 4 Celta Vigo (0.001)
# Real Sociedad 5 - 5 Celta Vigo (0.000)
# Real Sociedad 5 - 6 Celta Vigo (0.000)
# Real Sociedad 6 - 0 Celta Vigo (0.006)
# Real Sociedad 6 - 1 Celta Vigo (0.006)
# Real Sociedad 6 - 2 Celta Vigo (0.003)
# Real Sociedad 6 - 3 Celta Vigo (0.001)
# Real Sociedad 6 - 4 Celta Vigo (0.000)
# Real Sociedad 6 - 5 Celta Vigo (0.000)
# Real Sociedad 6 - 6 Celta Vigo (0.000)
# {'home_team': 'Real Sociedad', 'away_team': 'Celta Vigo', 'lambda_home': 2.1487603305785123, 'lambda_away': 0.9917355371900826, 'prob_over_2_goals': 0.4136640453162005, 'expected_goals': 3.140495867768595}
#
# Match 3: Real Betis vs Real Valladolid
#
# Simulation 1:
# Real Betis 0 - 0 Real Valladolid (0.022)
# Real Betis 0 - 1 Real Valladolid (0.015)
# Real Betis 0 - 2 Real Valladolid (0.005)
# Real Betis 0 - 3 Real Valladolid (0.001)
# Real Betis 0 - 4 Real Valladolid (0.000)
# Real Betis 0 - 5 Real Valladolid (0.000)
# Real Betis 0 - 6 Real Valladolid (0.000)
# Real Betis 1 - 0 Real Valladolid (0.069)
# Real Betis 1 - 1 Real Valladolid (0.048)
# Real Betis 1 - 2 Real Valladolid (0.017)
# Real Betis 1 - 3 Real Valladolid (0.004)
# Real Betis 1 - 4 Real Valladolid (0.001)
# Real Betis 1 - 5 Real Valladolid (0.000)
# Real Betis 1 - 6 Real Valladolid (0.000)
# Real Betis 2 - 0 Real Valladolid (0.107)
# Real Betis 2 - 1 Real Valladolid (0.074)
# Real Betis 2 - 2 Real Valladolid (0.026)
# Real Betis 2 - 3 Real Valladolid (0.006)
# Real Betis 2 - 4 Real Valladolid (0.001)
# Real Betis 2 - 5 Real Valladolid (0.000)
# Real Betis 2 - 6 Real Valladolid (0.000)
# Real Betis 3 - 0 Real Valladolid (0.112)
# Real Betis 3 - 1 Real Valladolid (0.077)
# Real Betis 3 - 2 Real Valladolid (0.027)
# Real Betis 3 - 3 Real Valladolid (0.006)
# Real Betis 3 - 4 Real Valladolid (0.001)
# Real Betis 3 - 5 Real Valladolid (0.000)
# Real Betis 3 - 6 Real Valladolid (0.000)
# Real Betis 4 - 0 Real Valladolid (0.087)
# Real Betis 4 - 1 Real Valladolid (0.061)
# Real Betis 4 - 2 Real Valladolid (0.021)
# Real Betis 4 - 3 Real Valladolid (0.005)
# Real Betis 4 - 4 Real Valladolid (0.001)
# Real Betis 4 - 5 Real Valladolid (0.000)
# Real Betis 4 - 6 Real Valladolid (0.000)
# Real Betis 5 - 0 Real Valladolid (0.054)
# Real Betis 5 - 1 Real Valladolid (0.038)
# Real Betis 5 - 2 Real Valladolid (0.013)
# Real Betis 5 - 3 Real Valladolid (0.003)
# Real Betis 5 - 4 Real Valladolid (0.001)
# Real Betis 5 - 5 Real Valladolid (0.000)
# Real Betis 5 - 6 Real Valladolid (0.000)
# Real Betis 6 - 0 Real Valladolid (0.028)
# Real Betis 6 - 1 Real Valladolid (0.020)
# Real Betis 6 - 2 Real Valladolid (0.007)
# Real Betis 6 - 3 Real Valladolid (0.002)
# Real Betis 6 - 4 Real Valladolid (0.000)
# Real Betis 6 - 5 Real Valladolid (0.000)
# Real Betis 6 - 6 Real Valladolid (0.000)
# {'home_team': 'Real Betis', 'away_team': 'Real Valladolid', 'lambda_home': 3.1239669421487606, 'lambda_away': 0.6942148760330578, 'prob_over_2_goals': 0.6172454274172721, 'expected_goals': 3.8181818181818183}
#
# Match 4: Mallorca vs Villarreal
#
# Simulation 1:
# Mallorca 0 - 0 Villarreal (0.153)
# Mallorca 0 - 1 Villarreal (0.093)
# Mallorca 0 - 2 Villarreal (0.028)
# Mallorca 0 - 3 Villarreal (0.006)
# Mallorca 0 - 4 Villarreal (0.001)
# Mallorca 0 - 5 Villarreal (0.000)
# Mallorca 0 - 6 Villarreal (0.000)
# Mallorca 1 - 0 Villarreal (0.194)
# Mallorca 1 - 1 Villarreal (0.118)
# Mallorca 1 - 2 Villarreal (0.036)
# Mallorca 1 - 3 Villarreal (0.007)
# Mallorca 1 - 4 Villarreal (0.001)
# Mallorca 1 - 5 Villarreal (0.000)
# Mallorca 1 - 6 Villarreal (0.000)
# Mallorca 2 - 0 Villarreal (0.124)
# Mallorca 2 - 1 Villarreal (0.075)
# Mallorca 2 - 2 Villarreal (0.023)
# Mallorca 2 - 3 Villarreal (0.005)
# Mallorca 2 - 4 Villarreal (0.001)
# Mallorca 2 - 5 Villarreal (0.000)
# Mallorca 2 - 6 Villarreal (0.000)
# Mallorca 3 - 0 Villarreal (0.052)
# Mallorca 3 - 1 Villarreal (0.032)
# Mallorca 3 - 2 Villarreal (0.010)
# Mallorca 3 - 3 Villarreal (0.002)
# Mallorca 3 - 4 Villarreal (0.000)
# Mallorca 3 - 5 Villarreal (0.000)
# Mallorca 3 - 6 Villarreal (0.000)
# Mallorca 4 - 0 Villarreal (0.017)
# Mallorca 4 - 1 Villarreal (0.010)
# Mallorca 4 - 2 Villarreal (0.003)
# Mallorca 4 - 3 Villarreal (0.001)
# Mallorca 4 - 4 Villarreal (0.000)
# Mallorca 4 - 5 Villarreal (0.000)
# Mallorca 4 - 6 Villarreal (0.000)
# Mallorca 5 - 0 Villarreal (0.004)
# Mallorca 5 - 1 Villarreal (0.003)
# Mallorca 5 - 2 Villarreal (0.001)
# Mallorca 5 - 3 Villarreal (0.000)
# Mallorca 5 - 4 Villarreal (0.000)
# Mallorca 5 - 5 Villarreal (0.000)
# Mallorca 5 - 6 Villarreal (0.000)
# Mallorca 6 - 0 Villarreal (0.001)
# Mallorca 6 - 1 Villarreal (0.001)
# Mallorca 6 - 2 Villarreal (0.000)
# Mallorca 6 - 3 Villarreal (0.000)
# Mallorca 6 - 4 Villarreal (0.000)
# Mallorca 6 - 5 Villarreal (0.000)
# Mallorca 6 - 6 Villarreal (0.000)
# {'home_team': 'Mallorca', 'away_team': 'Villarreal', 'lambda_home': 1.2727272727272727, 'lambda_away': 0.6060606060606061, 'prob_over_2_goals': 0.1571307452177091, 'expected_goals': 1.878787878787879}
#
# Match 5: Osasuna vs Real Madrid
#
# Simulation 1:
# Osasuna 0 - 0 Real Madrid (0.055)
# Osasuna 0 - 1 Real Madrid (0.109)
# Osasuna 0 - 2 Real Madrid (0.109)
# Osasuna 0 - 3 Real Madrid (0.073)
# Osasuna 0 - 4 Real Madrid (0.036)
# Osasuna 0 - 5 Real Madrid (0.015)
# Osasuna 0 - 6 Real Madrid (0.005)
# Osasuna 1 - 0 Real Madrid (0.050)
# Osasuna 1 - 1 Real Madrid (0.099)
# Osasuna 1 - 2 Real Madrid (0.099)
# Osasuna 1 - 3 Real Madrid (0.066)
# Osasuna 1 - 4 Real Madrid (0.033)
# Osasuna 1 - 5 Real Madrid (0.013)
# Osasuna 1 - 6 Real Madrid (0.004)
# Osasuna 2 - 0 Real Madrid (0.023)
# Osasuna 2 - 1 Real Madrid (0.045)
# Osasuna 2 - 2 Real Madrid (0.045)
# Osasuna 2 - 3 Real Madrid (0.030)
# Osasuna 2 - 4 Real Madrid (0.015)
# Osasuna 2 - 5 Real Madrid (0.006)
# Osasuna 2 - 6 Real Madrid (0.002)
# Osasuna 3 - 0 Real Madrid (0.007)
# Osasuna 3 - 1 Real Madrid (0.014)
# Osasuna 3 - 2 Real Madrid (0.014)
# Osasuna 3 - 3 Real Madrid (0.009)
# Osasuna 3 - 4 Real Madrid (0.005)
# Osasuna 3 - 5 Real Madrid (0.002)
# Osasuna 3 - 6 Real Madrid (0.001)
# Osasuna 4 - 0 Real Madrid (0.002)
# Osasuna 4 - 1 Real Madrid (0.003)
# Osasuna 4 - 2 Real Madrid (0.003)
# Osasuna 4 - 3 Real Madrid (0.002)
# Osasuna 4 - 4 Real Madrid (0.001)
# Osasuna 4 - 5 Real Madrid (0.000)
# Osasuna 4 - 6 Real Madrid (0.000)
# Osasuna 5 - 0 Real Madrid (0.000)
# Osasuna 5 - 1 Real Madrid (0.001)
# Osasuna 5 - 2 Real Madrid (0.001)
# Osasuna 5 - 3 Real Madrid (0.000)
# Osasuna 5 - 4 Real Madrid (0.000)
# Osasuna 5 - 5 Real Madrid (0.000)
# Osasuna 5 - 6 Real Madrid (0.000)
# Osasuna 6 - 0 Real Madrid (0.000)
# Osasuna 6 - 1 Real Madrid (0.000)
# Osasuna 6 - 2 Real Madrid (0.000)
# Osasuna 6 - 3 Real Madrid (0.000)
# Osasuna 6 - 4 Real Madrid (0.000)
# Osasuna 6 - 5 Real Madrid (0.000)
# Osasuna 6 - 6 Real Madrid (0.000)
# {'home_team': 'Osasuna', 'away_team': 'Real Madrid', 'lambda_home': 0.9090909090909091, 'lambda_away': 2.0, 'prob_over_2_goals': 0.36687593002234375, 'expected_goals': 2.909090909090909}
#
# Match 6: Elche vs Espanyol
#
# Simulation 1:
# Elche 0 - 0 Espanyol (0.048)
# Elche 0 - 1 Espanyol (0.092)
# Elche 0 - 2 Espanyol (0.088)
# Elche 0 - 3 Espanyol (0.056)
# Elche 0 - 4 Espanyol (0.027)
# Elche 0 - 5 Espanyol (0.010)
# Elche 0 - 6 Espanyol (0.003)
# Elche 1 - 0 Espanyol (0.054)
# Elche 1 - 1 Espanyol (0.103)
# Elche 1 - 2 Espanyol (0.099)
# Elche 1 - 3 Espanyol (0.063)
# Elche 1 - 4 Espanyol (0.030)
# Elche 1 - 5 Espanyol (0.012)
# Elche 1 - 6 Espanyol (0.004)
# Elche 2 - 0 Espanyol (0.030)
# Elche 2 - 1 Espanyol (0.058)
# Elche 2 - 2 Espanyol (0.055)
# Elche 2 - 3 Espanyol (0.035)
# Elche 2 - 4 Espanyol (0.017)
# Elche 2 - 5 Espanyol (0.007)
# Elche 2 - 6 Espanyol (0.002)
# Elche 3 - 0 Espanyol (0.011)
# Elche 3 - 1 Espanyol (0.022)
# Elche 3 - 2 Espanyol (0.021)
# Elche 3 - 3 Espanyol (0.013)
# Elche 3 - 4 Espanyol (0.006)
# Elche 3 - 5 Espanyol (0.002)
# Elche 3 - 6 Espanyol (0.001)
# Elche 4 - 0 Espanyol (0.003)
# Elche 4 - 1 Espanyol (0.006)
# Elche 4 - 2 Espanyol (0.006)
# Elche 4 - 3 Espanyol (0.004)
# Elche 4 - 4 Espanyol (0.002)
# Elche 4 - 5 Espanyol (0.001)
# Elche 4 - 6 Espanyol (0.000)
# Elche 5 - 0 Espanyol (0.001)
# Elche 5 - 1 Espanyol (0.001)
# Elche 5 - 2 Espanyol (0.001)
# Elche 5 - 3 Espanyol (0.001)
# Elche 5 - 4 Espanyol (0.000)
# Elche 5 - 5 Espanyol (0.000)
# Elche 5 - 6 Espanyol (0.000)
# Elche 6 - 0 Espanyol (0.000)
# Elche 6 - 1 Espanyol (0.000)
# Elche 6 - 2 Espanyol (0.000)
# Elche 6 - 3 Espanyol (0.000)
# Elche 6 - 4 Espanyol (0.000)
# Elche 6 - 5 Espanyol (0.000)
# Elche 6 - 6 Espanyol (0.000)
# {'home_team': 'Elche', 'away_team': 'Espanyol', 'lambda_home': 1.1199999999999999, 'lambda_away': 1.92, 'prob_over_2_goals': 0.3740583215011829, 'expected_goals': 3.04}
#
# Match 7: Rayo Vallecano vs Sevilla
#
# Simulation 1:
# Rayo Vallecano 0 - 0 Sevilla (0.023)
# Rayo Vallecano 0 - 1 Sevilla (0.028)
# Rayo Vallecano 0 - 2 Sevilla (0.017)
# Rayo Vallecano 0 - 3 Sevilla (0.007)
# Rayo Vallecano 0 - 4 Sevilla (0.002)
# Rayo Vallecano 0 - 5 Sevilla (0.001)
# Rayo Vallecano 0 - 6 Sevilla (0.000)
# Rayo Vallecano 1 - 0 Sevilla (0.059)
# Rayo Vallecano 1 - 1 Sevilla (0.072)
# Rayo Vallecano 1 - 2 Sevilla (0.043)
# Rayo Vallecano 1 - 3 Sevilla (0.018)
# Rayo Vallecano 1 - 4 Sevilla (0.005)
# Rayo Vallecano 1 - 5 Sevilla (0.001)
# Rayo Vallecano 1 - 6 Sevilla (0.000)
# Rayo Vallecano 2 - 0 Sevilla (0.076)
# Rayo Vallecano 2 - 1 Sevilla (0.092)
# Rayo Vallecano 2 - 2 Sevilla (0.055)
# Rayo Vallecano 2 - 3 Sevilla (0.022)
# Rayo Vallecano 2 - 4 Sevilla (0.007)
# Rayo Vallecano 2 - 5 Sevilla (0.002)
# Rayo Vallecano 2 - 6 Sevilla (0.000)
# Rayo Vallecano 3 - 0 Sevilla (0.064)
# Rayo Vallecano 3 - 1 Sevilla (0.078)
# Rayo Vallecano 3 - 2 Sevilla (0.047)
# Rayo Vallecano 3 - 3 Sevilla (0.019)
# Rayo Vallecano 3 - 4 Sevilla (0.006)
# Rayo Vallecano 3 - 5 Sevilla (0.001)
# Rayo Vallecano 3 - 6 Sevilla (0.000)
# Rayo Vallecano 4 - 0 Sevilla (0.041)
# Rayo Vallecano 4 - 1 Sevilla (0.050)
# Rayo Vallecano 4 - 2 Sevilla (0.030)
# Rayo Vallecano 4 - 3 Sevilla (0.012)
# Rayo Vallecano 4 - 4 Sevilla (0.004)
# Rayo Vallecano 4 - 5 Sevilla (0.001)
# Rayo Vallecano 4 - 6 Sevilla (0.000)
# Rayo Vallecano 5 - 0 Sevilla (0.021)
# Rayo Vallecano 5 - 1 Sevilla (0.025)
# Rayo Vallecano 5 - 2 Sevilla (0.015)
# Rayo Vallecano 5 - 3 Sevilla (0.006)
# Rayo Vallecano 5 - 4 Sevilla (0.002)
# Rayo Vallecano 5 - 5 Sevilla (0.000)
# Rayo Vallecano 5 - 6 Sevilla (0.000)
# Rayo Vallecano 6 - 0 Sevilla (0.009)
# Rayo Vallecano 6 - 1 Sevilla (0.011)
# Rayo Vallecano 6 - 2 Sevilla (0.007)
# Rayo Vallecano 6 - 3 Sevilla (0.003)
# Rayo Vallecano 6 - 4 Sevilla (0.001)
# Rayo Vallecano 6 - 5 Sevilla (0.000)
# Rayo Vallecano 6 - 6 Sevilla (0.000)
# {'home_team': 'Rayo Vallecano', 'away_team': 'Sevilla', 'lambda_home': 2.55, 'lambda_away': 1.2100000000000002, 'prob_over_2_goals': 0.5341012596737708, 'expected_goals': 3.76}
#
# Match 8: Atletico Madrid vs Athletic Club
#
# Simulation 1:
# Atletico Madrid 0 - 0 Athletic Club (0.024)
# Atletico Madrid 0 - 1 Athletic Club (0.035)
# Atletico Madrid 0 - 2 Athletic Club (0.026)
# Atletico Madrid 0 - 3 Athletic Club (0.013)
# Atletico Madrid 0 - 4 Athletic Club (0.005)
# Atletico Madrid 0 - 5 Athletic Club (0.001)
# Atletico Madrid 0 - 6 Athletic Club (0.000)
# Atletico Madrid 1 - 0 Athletic Club (0.053)
# Atletico Madrid 1 - 1 Athletic Club (0.079)
# Atletico Madrid 1 - 2 Athletic Club (0.060)
# Atletico Madrid 1 - 3 Athletic Club (0.030)
# Atletico Madrid 1 - 4 Athletic Club (0.011)
# Atletico Madrid 1 - 5 Athletic Club (0.003)
# Atletico Madrid 1 - 6 Athletic Club (0.001)
# Atletico Madrid 2 - 0 Athletic Club (0.060)
# Atletico Madrid 2 - 1 Athletic Club (0.089)
# Atletico Madrid 2 - 2 Athletic Club (0.067)
# Atletico Madrid 2 - 3 Athletic Club (0.033)
# Atletico Madrid 2 - 4 Athletic Club (0.013)
# Atletico Madrid 2 - 5 Athletic Club (0.004)
# Atletico Madrid 2 - 6 Athletic Club (0.001)
# Atletico Madrid 3 - 0 Athletic Club (0.045)
# Atletico Madrid 3 - 1 Athletic Club (0.067)
# Atletico Madrid 3 - 2 Athletic Club (0.050)
# Atletico Madrid 3 - 3 Athletic Club (0.025)
# Atletico Madrid 3 - 4 Athletic Club (0.009)
# Atletico Madrid 3 - 5 Athletic Club (0.003)
# Atletico Madrid 3 - 6 Athletic Club (0.001)
# Atletico Madrid 4 - 0 Athletic Club (0.025)
# Atletico Madrid 4 - 1 Athletic Club (0.038)
# Atletico Madrid 4 - 2 Athletic Club (0.028)
# Atletico Madrid 4 - 3 Athletic Club (0.014)
# Atletico Madrid 4 - 4 Athletic Club (0.005)
# Atletico Madrid 4 - 5 Athletic Club (0.002)
# Atletico Madrid 4 - 6 Athletic Club (0.000)
# Atletico Madrid 5 - 0 Athletic Club (0.011)
# Atletico Madrid 5 - 1 Athletic Club (0.017)
# Atletico Madrid 5 - 2 Athletic Club (0.013)
# Atletico Madrid 5 - 3 Athletic Club (0.006)
# Atletico Madrid 5 - 4 Athletic Club (0.002)
# Atletico Madrid 5 - 5 Athletic Club (0.001)
# Atletico Madrid 5 - 6 Athletic Club (0.000)
# Atletico Madrid 6 - 0 Athletic Club (0.004)
# Atletico Madrid 6 - 1 Athletic Club (0.006)
# Atletico Madrid 6 - 2 Athletic Club (0.005)
# Atletico Madrid 6 - 3 Athletic Club (0.002)
# Atletico Madrid 6 - 4 Athletic Club (0.001)
# Atletico Madrid 6 - 5 Athletic Club (0.000)
# Atletico Madrid 6 - 6 Athletic Club (0.000)
# {'home_team': 'Atletico Madrid', 'away_team': 'Athletic Club', 'lambda_home': 2.25, 'lambda_away': 1.5, 'prob_over_2_goals': 0.5071378651660592, 'expected_goals': 3.75}
#
# Match 9: Barcelona vs Cadiz
#
# Simulation 1:
# Barcelona 0 - 0 Cadiz (0.018)
# Barcelona 0 - 1 Cadiz (0.001)
# Barcelona 0 - 2 Cadiz (0.000)
# Barcelona 0 - 3 Cadiz (0.000)
# Barcelona 0 - 4 Cadiz (0.000)
# Barcelona 0 - 5 Cadiz (0.000)
# Barcelona 0 - 6 Cadiz (0.000)
# Barcelona 1 - 0 Cadiz (0.071)
# Barcelona 1 - 1 Cadiz (0.004)
# Barcelona 1 - 2 Cadiz (0.000)
# Barcelona 1 - 3 Cadiz (0.000)
# Barcelona 1 - 4 Cadiz (0.000)
# Barcelona 1 - 5 Cadiz (0.000)
# Barcelona 1 - 6 Cadiz (0.000)
# Barcelona 2 - 0 Cadiz (0.141)
# Barcelona 2 - 1 Cadiz (0.008)
# Barcelona 2 - 2 Cadiz (0.000)
# Barcelona 2 - 3 Cadiz (0.000)
# Barcelona 2 - 4 Cadiz (0.000)
# Barcelona 2 - 5 Cadiz (0.000)
# Barcelona 2 - 6 Cadiz (0.000)
# Barcelona 3 - 0 Cadiz (0.186)
# Barcelona 3 - 1 Cadiz (0.011)
# Barcelona 3 - 2 Cadiz (0.000)
# Barcelona 3 - 3 Cadiz (0.000)
# Barcelona 3 - 4 Cadiz (0.000)
# Barcelona 3 - 5 Cadiz (0.000)
# Barcelona 3 - 6 Cadiz (0.000)
# Barcelona 4 - 0 Cadiz (0.184)
# Barcelona 4 - 1 Cadiz (0.011)
# Barcelona 4 - 2 Cadiz (0.000)
# Barcelona 4 - 3 Cadiz (0.000)
# Barcelona 4 - 4 Cadiz (0.000)
# Barcelona 4 - 5 Cadiz (0.000)
# Barcelona 4 - 6 Cadiz (0.000)
# Barcelona 5 - 0 Cadiz (0.146)
# Barcelona 5 - 1 Cadiz (0.009)
# Barcelona 5 - 2 Cadiz (0.000)
# Barcelona 5 - 3 Cadiz (0.000)
# Barcelona 5 - 4 Cadiz (0.000)
# Barcelona 5 - 5 Cadiz (0.000)
# Barcelona 5 - 6 Cadiz (0.000)
# Barcelona 6 - 0 Cadiz (0.096)
# Barcelona 6 - 1 Cadiz (0.006)
# Barcelona 6 - 2 Cadiz (0.000)
# Barcelona 6 - 3 Cadiz (0.000)
# Barcelona 6 - 4 Cadiz (0.000)
# Barcelona 6 - 5 Cadiz (0.000)
# Barcelona 6 - 6 Cadiz (0.000)
# {'home_team': 'Barcelona', 'away_team': 'Cadiz', 'lambda_home': 3.9600000000000004, 'lambda_away': 0.059999999999999984, 'prob_over_2_goals': 0.7559852854220809, 'expected_goals': 4.0200000000000005}
#
# Match 10: Getafe vs Valencia
#
# Simulation 1:
# Getafe 0 - 0 Valencia (0.101)
# Getafe 0 - 1 Valencia (0.103)
# Getafe 0 - 2 Valencia (0.052)
# Getafe 0 - 3 Valencia (0.018)
# Getafe 0 - 4 Valencia (0.005)
# Getafe 0 - 5 Valencia (0.001)
# Getafe 0 - 6 Valencia (0.000)
# Getafe 1 - 0 Valencia (0.129)
# Getafe 1 - 1 Valencia (0.131)
# Getafe 1 - 2 Valencia (0.067)
# Getafe 1 - 3 Valencia (0.023)
# Getafe 1 - 4 Valencia (0.006)
# Getafe 1 - 5 Valencia (0.001)
# Getafe 1 - 6 Valencia (0.000)
# Getafe 2 - 0 Valencia (0.082)
# Getafe 2 - 1 Valencia (0.083)
# Getafe 2 - 2 Valencia (0.042)
# Getafe 2 - 3 Valencia (0.014)
# Getafe 2 - 4 Valencia (0.004)
# Getafe 2 - 5 Valencia (0.001)
# Getafe 2 - 6 Valencia (0.000)
# Getafe 3 - 0 Valencia (0.035)
# Getafe 3 - 1 Valencia (0.035)
# Getafe 3 - 2 Valencia (0.018)
# Getafe 3 - 3 Valencia (0.006)
# Getafe 3 - 4 Valencia (0.002)
# Getafe 3 - 5 Valencia (0.000)
# Getafe 3 - 6 Valencia (0.000)
# Getafe 4 - 0 Valencia (0.011)
# Getafe 4 - 1 Valencia (0.011)
# Getafe 4 - 2 Valencia (0.006)
# Getafe 4 - 3 Valencia (0.002)
# Getafe 4 - 4 Valencia (0.000)
# Getafe 4 - 5 Valencia (0.000)
# Getafe 4 - 6 Valencia (0.000)
# Getafe 5 - 0 Valencia (0.003)
# Getafe 5 - 1 Valencia (0.003)
# Getafe 5 - 2 Valencia (0.001)
# Getafe 5 - 3 Valencia (0.000)
# Getafe 5 - 4 Valencia (0.000)
# Getafe 5 - 5 Valencia (0.000)
# Getafe 5 - 6 Valencia (0.000)
# Getafe 6 - 0 Valencia (0.001)
# Getafe 6 - 1 Valencia (0.001)
# Getafe 6 - 2 Valencia (0.000)
# Getafe 6 - 3 Valencia (0.000)
# Getafe 6 - 4 Valencia (0.000)
# Getafe 6 - 5 Valencia (0.000)
# Getafe 6 - 6 Valencia (0.000)
# {'home_team': 'Getafe', 'away_team': 'Valencia', 'lambda_home': 1.2727272727272727, 'lambda_away': 1.0181818181818183, 'prob_over_2_goals': 0.20889504627016475, 'expected_goals': 2.290909090909091}

# %% [markdown]
# ## Export the Output into a Word Document

# %%
from docx import Document
from docx.shared import Inches
from datetime import date

# Create a new Word document
doc = Document()

# Add a title with today's date
doc.add_heading(f"La Liga predictions - {date.today().strftime('%B %d, %Y')}", 0)

# Loop through the matchdays and add the predictions to the document
for i, matchday in df_matchdays.iterrows():
    home_team = matchday['home_team']
    away_team = matchday['away_team']
    prediction = predict_game_result(home_team, away_team, df_merged)

    # Add a heading with the match details
    doc.add_heading(f"Match {i+1}: {home_team} vs. {away_team}", level=1)

    # Add the simulation results
    doc.add_paragraph("Simulation Results:")
    for sim in range(3):
        for j in range(3):
            score_prob = poisson.pmf(sim, prediction['lambda_home']) * poisson.pmf(j, prediction['lambda_away'])
            doc.add_paragraph(f"{home_team} {sim} - {j} {away_team} ({score_prob:.3f})")

    # Add the prediction results
    doc.add_paragraph("Prediction Results:")
    doc.add_paragraph(f"Expected goals: {prediction['expected_goals']:.2f}")
    doc.add_paragraph(f"Probability of over 2 goals: {prediction['prob_over_2_goals']:.2f}")

    # Add a page break after each match
    doc.add_page_break()

# Save the document with the current date in the filename
doc.save(f"La Liga matchday_predictions_{date.today().strftime('%Y-%m-%d')}.docx")
# Out:
# Simulation 1:
# Girona 0 - 0 Almeria (0.005)
# Girona 0 - 1 Almeria (0.005)
# Girona 0 - 2 Almeria (0.002)
# Girona 0 - 3 Almeria (0.001)
# Girona 0 - 4 Almeria (0.000)
# Girona 1 - 0 Almeria (0.020)
# Girona 1 - 1 Almeria (0.021)
# Girona 1 - 2 Almeria (0.011)
# Girona 1 - 3 Almeria (0.004)
# Girona 1 - 4 Almeria (0.001)
# Girona 2 - 0 Almeria (0.043)
# Girona 2 - 1 Almeria (0.045)
# Girona 2 - 2 Almeria (0.023)
# Girona 2 - 3 Almeria (0.008)
# Girona 2 - 4 Almeria (0.002)
# Girona 3 - 0 Almeria (0.063)
# Girona 3 - 1 Almeria (0.065)
# Girona 3 - 2 Almeria (0.033)
# Girona 3 - 3 Almeria (0.011)
# Girona 3 - 4 Almeria (0.003)
# Girona 4 - 0 Almeria (0.069)
# Girona 4 - 1 Almeria (0.071)
# Girona 4 - 2 Almeria (0.036)
# Girona 4 - 3 Almeria (0.013)
# Girona 4 - 4 Almeria (0.003)
# Simulation 1:
# Real Sociedad 0 - 0 Celta Vigo (0.043)
# Real Sociedad 0 - 1 Celta Vigo (0.043)
# Real Sociedad 0 - 2 Celta Vigo (0.021)
# Real Sociedad 0 - 3 Celta Vigo (0.007)
# Real Sociedad 0 - 4 Celta Vigo (0.002)
# Real Sociedad 1 - 0 Celta Vigo (0.093)
# Real Sociedad 1 - 1 Celta Vigo (0.092)
# Real Sociedad 1 - 2 Celta Vigo (0.046)
# Real Sociedad 1 - 3 Celta Vigo (0.015)
# Real Sociedad 1 - 4 Celta Vigo (0.004)
# Real Sociedad 2 - 0 Celta Vigo (0.100)
# Real Sociedad 2 - 1 Celta Vigo (0.099)
# Real Sociedad 2 - 2 Celta Vigo (0.049)
# Real Sociedad 2 - 3 Celta Vigo (0.016)
# Real Sociedad 2 - 4 Celta Vigo (0.004)
# Real Sociedad 3 - 0 Celta Vigo (0.072)
# Real Sociedad 3 - 1 Celta Vigo (0.071)
# Real Sociedad 3 - 2 Celta Vigo (0.035)
# Real Sociedad 3 - 3 Celta Vigo (0.012)
# Real Sociedad 3 - 4 Celta Vigo (0.003)
# Real Sociedad 4 - 0 Celta Vigo (0.038)
# Real Sociedad 4 - 1 Celta Vigo (0.038)
# Real Sociedad 4 - 2 Celta Vigo (0.019)
# Real Sociedad 4 - 3 Celta Vigo (0.006)
# Real Sociedad 4 - 4 Celta Vigo (0.002)
# Simulation 1:
# Real Betis 0 - 0 Real Valladolid (0.022)
# Real Betis 0 - 1 Real Valladolid (0.015)
# Real Betis 0 - 2 Real Valladolid (0.005)
# Real Betis 0 - 3 Real Valladolid (0.001)
# Real Betis 0 - 4 Real Valladolid (0.000)
# Real Betis 1 - 0 Real Valladolid (0.069)
# Real Betis 1 - 1 Real Valladolid (0.048)
# Real Betis 1 - 2 Real Valladolid (0.017)
# Real Betis 1 - 3 Real Valladolid (0.004)
# Real Betis 1 - 4 Real Valladolid (0.001)
# Real Betis 2 - 0 Real Valladolid (0.107)
# Real Betis 2 - 1 Real Valladolid (0.074)
# Real Betis 2 - 2 Real Valladolid (0.026)
# Real Betis 2 - 3 Real Valladolid (0.006)
# Real Betis 2 - 4 Real Valladolid (0.001)
# Real Betis 3 - 0 Real Valladolid (0.112)
# Real Betis 3 - 1 Real Valladolid (0.077)
# Real Betis 3 - 2 Real Valladolid (0.027)
# Real Betis 3 - 3 Real Valladolid (0.006)
# Real Betis 3 - 4 Real Valladolid (0.001)
# Real Betis 4 - 0 Real Valladolid (0.087)
# Real Betis 4 - 1 Real Valladolid (0.061)
# Real Betis 4 - 2 Real Valladolid (0.021)
# Real Betis 4 - 3 Real Valladolid (0.005)
# Real Betis 4 - 4 Real Valladolid (0.001)
# Simulation 1:
# Mallorca 0 - 0 Villarreal (0.153)
# Mallorca 0 - 1 Villarreal (0.093)
# Mallorca 0 - 2 Villarreal (0.028)
# Mallorca 0 - 3 Villarreal (0.006)
# Mallorca 0 - 4 Villarreal (0.001)
# Mallorca 1 - 0 Villarreal (0.194)
# Mallorca 1 - 1 Villarreal (0.118)
# Mallorca 1 - 2 Villarreal (0.036)
# Mallorca 1 - 3 Villarreal (0.007)
# Mallorca 1 - 4 Villarreal (0.001)
# Mallorca 2 - 0 Villarreal (0.124)
# Mallorca 2 - 1 Villarreal (0.075)
# Mallorca 2 - 2 Villarreal (0.023)
# Mallorca 2 - 3 Villarreal (0.005)
# Mallorca 2 - 4 Villarreal (0.001)
# Mallorca 3 - 0 Villarreal (0.052)
# Mallorca 3 - 1 Villarreal (0.032)
# Mallorca 3 - 2 Villarreal (0.010)
# Mallorca 3 - 3 Villarreal (0.002)
# Mallorca 3 - 4 Villarreal (0.000)
# Mallorca 4 - 0 Villarreal (0.017)
# Mallorca 4 - 1 Villarreal (0.010)
# Mallorca 4 - 2 Villarreal (0.003)
# Mallorca 4 - 3 Villarreal (0.001)
# Mallorca 4 - 4 Villarreal (0.000)
# Simulation 1:
# Osasuna 0 - 0 Real Madrid (0.055)
# Osasuna 0 - 1 Real Madrid (0.109)
# Osasuna 0 - 2 Real Madrid (0.109)
# Osasuna 0 - 3 Real Madrid (0.073)
# Osasuna 0 - 4 Real Madrid (0.036)
# Osasuna 1 - 0 Real Madrid (0.050)
# Osasuna 1 - 1 Real Madrid (0.099)
# Osasuna 1 - 2 Real Madrid (0.099)
# Osasuna 1 - 3 Real Madrid (0.066)
# Osasuna 1 - 4 Real Madrid (0.033)
# Osasuna 2 - 0 Real Madrid (0.023)
# Osasuna 2 - 1 Real Madrid (0.045)
# Osasuna 2 - 2 Real Madrid (0.045)
# Osasuna 2 - 3 Real Madrid (0.030)
# Osasuna 2 - 4 Real Madrid (0.015)
# Osasuna 3 - 0 Real Madrid (0.007)
# Osasuna 3 - 1 Real Madrid (0.014)
# Osasuna 3 - 2 Real Madrid (0.014)
# Osasuna 3 - 3 Real Madrid (0.009)
# Osasuna 3 - 4 Real Madrid (0.005)
# Osasuna 4 - 0 Real Madrid (0.002)
# Osasuna 4 - 1 Real Madrid (0.003)
# Osasuna 4 - 2 Real Madrid (0.003)
# Osasuna 4 - 3 Real Madrid (0.002)
# Osasuna 4 - 4 Real Madrid (0.001)
# Simulation 1:
# Elche 0 - 0 Espanyol (0.048)
# Elche 0 - 1 Espanyol (0.092)
# Elche 0 - 2 Espanyol (0.088)
# Elche 0 - 3 Espanyol (0.056)
# Elche 0 - 4 Espanyol (0.027)
# Elche 1 - 0 Espanyol (0.054)
# Elche 1 - 1 Espanyol (0.103)
# Elche 1 - 2 Espanyol (0.099)
# Elche 1 - 3 Espanyol (0.063)
# Elche 1 - 4 Espanyol (0.030)
# Elche 2 - 0 Espanyol (0.030)
# Elche 2 - 1 Espanyol (0.058)
# Elche 2 - 2 Espanyol (0.055)
# Elche 2 - 3 Espanyol (0.035)
# Elche 2 - 4 Espanyol (0.017)
# Elche 3 - 0 Espanyol (0.011)
# Elche 3 - 1 Espanyol (0.022)
# Elche 3 - 2 Espanyol (0.021)
# Elche 3 - 3 Espanyol (0.013)
# Elche 3 - 4 Espanyol (0.006)
# Elche 4 - 0 Espanyol (0.003)
# Elche 4 - 1 Espanyol (0.006)
# Elche 4 - 2 Espanyol (0.006)
# Elche 4 - 3 Espanyol (0.004)
# Elche 4 - 4 Espanyol (0.002)
# Simulation 1:
# Rayo Vallecano 0 - 0 Sevilla (0.023)
# Rayo Vallecano 0 - 1 Sevilla (0.028)
# Rayo Vallecano 0 - 2 Sevilla (0.017)
# Rayo Vallecano 0 - 3 Sevilla (0.007)
# Rayo Vallecano 0 - 4 Sevilla (0.002)
# Rayo Vallecano 1 - 0 Sevilla (0.059)
# Rayo Vallecano 1 - 1 Sevilla (0.072)
# Rayo Vallecano 1 - 2 Sevilla (0.043)
# Rayo Vallecano 1 - 3 Sevilla (0.018)
# Rayo Vallecano 1 - 4 Sevilla (0.005)
# Rayo Vallecano 2 - 0 Sevilla (0.076)
# Rayo Vallecano 2 - 1 Sevilla (0.092)
# Rayo Vallecano 2 - 2 Sevilla (0.055)
# Rayo Vallecano 2 - 3 Sevilla (0.022)
# Rayo Vallecano 2 - 4 Sevilla (0.007)
# Rayo Vallecano 3 - 0 Sevilla (0.064)
# Rayo Vallecano 3 - 1 Sevilla (0.078)
# Rayo Vallecano 3 - 2 Sevilla (0.047)
# Rayo Vallecano 3 - 3 Sevilla (0.019)
# Rayo Vallecano 3 - 4 Sevilla (0.006)
# Rayo Vallecano 4 - 0 Sevilla (0.041)
# Rayo Vallecano 4 - 1 Sevilla (0.050)
# Rayo Vallecano 4 - 2 Sevilla (0.030)
# Rayo Vallecano 4 - 3 Sevilla (0.012)
# Rayo Vallecano 4 - 4 Sevilla (0.004)
# Simulation 1:
# Atletico Madrid 0 - 0 Athletic Club (0.024)
# Atletico Madrid 0 - 1 Athletic Club (0.035)
# Atletico Madrid 0 - 2 Athletic Club (0.026)
# Atletico Madrid 0 - 3 Athletic Club (0.013)
# Atletico Madrid 0 - 4 Athletic Club (0.005)
# Atletico Madrid 1 - 0 Athletic Club (0.053)
# Atletico Madrid 1 - 1 Athletic Club (0.079)
# Atletico Madrid 1 - 2 Athletic Club (0.060)
# Atletico Madrid 1 - 3 Athletic Club (0.030)
# Atletico Madrid 1 - 4 Athletic Club (0.011)
# Atletico Madrid 2 - 0 Athletic Club (0.060)
# Atletico Madrid 2 - 1 Athletic Club (0.089)
# Atletico Madrid 2 - 2 Athletic Club (0.067)
# Atletico Madrid 2 - 3 Athletic Club (0.033)
# Atletico Madrid 2 - 4 Athletic Club (0.013)
# Atletico Madrid 3 - 0 Athletic Club (0.045)
# Atletico Madrid 3 - 1 Athletic Club (0.067)
# Atletico Madrid 3 - 2 Athletic Club (0.050)
# Atletico Madrid 3 - 3 Athletic Club (0.025)
# Atletico Madrid 3 - 4 Athletic Club (0.009)
# Atletico Madrid 4 - 0 Athletic Club (0.025)
# Atletico Madrid 4 - 1 Athletic Club (0.038)
# Atletico Madrid 4 - 2 Athletic Club (0.028)
# Atletico Madrid 4 - 3 Athletic Club (0.014)
# Atletico Madrid 4 - 4 Athletic Club (0.005)
# Simulation 1:
# Barcelona 0 - 0 Cadiz (0.018)
# Barcelona 0 - 1 Cadiz (0.001)
# Barcelona 0 - 2 Cadiz (0.000)
# Barcelona 0 - 3 Cadiz (0.000)
# Barcelona 0 - 4 Cadiz (0.000)
# Barcelona 1 - 0 Cadiz (0.071)
# Barcelona 1 - 1 Cadiz (0.004)
# Barcelona 1 - 2 Cadiz (0.000)
# Barcelona 1 - 3 Cadiz (0.000)
# Barcelona 1 - 4 Cadiz (0.000)
# Barcelona 2 - 0 Cadiz (0.141)
# Barcelona 2 - 1 Cadiz (0.008)
# Barcelona 2 - 2 Cadiz (0.000)
# Barcelona 2 - 3 Cadiz (0.000)
# Barcelona 2 - 4 Cadiz (0.000)
# Barcelona 3 - 0 Cadiz (0.186)
# Barcelona 3 - 1 Cadiz (0.011)
# Barcelona 3 - 2 Cadiz (0.000)
# Barcelona 3 - 3 Cadiz (0.000)
# Barcelona 3 - 4 Cadiz (0.000)
# Barcelona 4 - 0 Cadiz (0.184)
# Barcelona 4 - 1 Cadiz (0.011)
# Barcelona 4 - 2 Cadiz (0.000)
# Barcelona 4 - 3 Cadiz (0.000)
# Barcelona 4 - 4 Cadiz (0.000)
# Simulation 1:
# Getafe 0 - 0 Valencia (0.101)
# Getafe 0 - 1 Valencia (0.103)
# Getafe 0 - 2 Valencia (0.052)
# Getafe 0 - 3 Valencia (0.018)
# Getafe 0 - 4 Valencia (0.005)
# Getafe 1 - 0 Valencia (0.129)
# Getafe 1 - 1 Valencia (0.131)
# Getafe 1 - 2 Valencia (0.067)
# Getafe 1 - 3 Valencia (0.023)
# Getafe 1 - 4 Valencia (0.006)
# Getafe 2 - 0 Valencia (0.082)
# Getafe 2 - 1 Valencia (0.083)
# Getafe 2 - 2 Valencia (0.042)
# Getafe 2 - 3 Valencia (0.014)
# Getafe 2 - 4 Valencia (0.004)
# Getafe 3 - 0 Valencia (0.035)
# Getafe 3 - 1 Valencia (0.035)
# Getafe 3 - 2 Valencia (0.018)
# Getafe 3 - 3 Valencia (0.006)
# Getafe 3 - 4 Valencia (0.002)
# Getafe 4 - 0 Valencia (0.011)
# Getafe 4 - 1 Valencia (0.011)
# Getafe 4 - 2 Valencia (0.006)
# Getafe 4 - 3 Valencia (0.002)
# Getafe 4 - 4 Valencia (0.000)
